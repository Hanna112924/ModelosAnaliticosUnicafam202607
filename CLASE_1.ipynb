# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanna112924/ModelosAnaliticosUnicafam202607/blob/main/CLASE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCIÓN PYTHON**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: ANA GARCIA

# %% [markdown]
# ## COMENTARIOS DE CODIGOS

# %%
#ESTE ES UN COMENTARIO DE UNA SOLA LINEA
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
"""
ESTE ES
UN COMENTARIO
DE VARIAS LINEAS
"""
# Out:
# '\nESTE ES \nUN COMENTARIO\nDE VARIAS LINEAS\n'

# %% [markdown]
# ## VARIABLES

# %%
var="Hola Mundo"
print(var)
# Out:
# Hola Mundo

# %%
#1. LAS VARIABLES PREFERIBLEMENTE DEBEN SER EN MINUSCULA
#2. LAS VARIBALES NO DEBEN TENER ESPACIOS
#3. LAS VARIABLES NO DEBEN TENER CARACTERES ESPECIALES

# %% [markdown]
# ## TIPOS DE DATOS

# %%
# ENTEROS
entero=5
entero_explicito=int(5)

#DECIMALES
decimal=5.0
decimal_explicito=float(5.0)

# %%
type(entero)
# Out:
# int

# %% [markdown]
# ## OPERADORES ARITMETICOS

# %%
a=10
b=5
c=a+b
print(a+b)
print(c)
# Out:
# 15
# 15

# %%
# DIVISION ENTERA
print(a//b)
# Out:
# 2

# %%
# MODULO
print(a%b)
# Out:
# 0

# %%
# EXPONENCIACION
print(b**2)
# Out:
# 25

# %%
# ASIGNACION COMPUESTA
b+=2
print(b)
# Out:
# 7

# %% [markdown]
# ## TEXTOS

# %%
cadena="python es genial"
print(cadena[5])
# Out:
# n

# %%
# EXTRAER LA PALABRA PYTHON
print(cadena[0:6])
# Out:
# python

# %%
# EXTRAER LA PALABRA GENIAL
print(cadena[9:16])
# Out:
#  genial

# %%
# CONCATENACIÓN DE VALORES
palabra1="Hola"
palabra2="Mundo"
print(palabra1+","+palabra2)
# Out:
# Hola,Mundo

# %%
# CAMBIOS DE FORMATOS
print(cadena.upper())
# Out:
# PYTHON ES GENIAL

# %%
# CAMBIOS DE FORMATO
print(cadena.lower())
# Out:
# python es genial
