# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanna112924/ModelosAnaliticosUnicafam202607/blob/main/Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ESTRUCTURAS DE DATOS**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: ANA GARCIA

# %% [markdown]
# # LISTAS

# %%
# Una lista vacia
mi_lista=[]
# Lista con varios elementos
mi_lista=[1,2,3,"4",5.0,True]
print(mi_lista)
# Out:
# 3

# %%
# Cambios en la lista
mi_lista[0]="Ana"
print(mi_lista)
# Out:
# ['Ana', 2, 3, '4', 5.0, True]

# %%
# Agregar elementos a una lista
mi_lista.append("Garcia")
print(mi_lista)
# Out:
# ['Ana', 2, 3, '4', 5.0, True, 'Garcia']

# %%
# Agregar elementos en una posición especifica
mi_lista.insert(3,"Bogota")
print(mi_lista)
# Out:
# ['Ana', 2, 3, 'Bogota', '4', 5.0, True, 'Garcia']

# %%
# Agregar varios elementos al final de la lista
mi_lista.extend([7,False])
print(mi_lista)
# Out:
# ['Ana', 2, 3, 'Bogota', '4', 5.0, True, 'Garcia', 7, False]

# %%
# Quitar elementos
# Eliminar objetos especificos
mi_lista.remove(True)
print(mi_lista)
# Out:
# ['Ana', 2, 3, 'Bogota', '4', 5.0, 'Garcia', 7, False]

# %%
print("ACTUALIZACIÓN DE DATOS")
valor_buscar=input("Por favor, ingrese el nombre para actualizar:")
valor_reemplazar=input("Ingrese valor a reemplazar:")
mi_lista[mi_lista.index(valor_buscar)]=valor_reemplazar
print("Cambio ejecutado.Imprimiendo resultado")
print(mi_lista)
# Out:
# ACTUALIZACIÓN DE DATOS
# Por favor, ingrese el nombre para actualizar:Ana
# Ingrese valor a reemplazar:Maria
# Cambio ejecutado.Imprimiendo resultado
# ['Maria', 2, 3, 'Bogota', '4', 5.0, 'Garcia', 7, False]

# %% [markdown]
# # DICCIONARIOS

# %%
mi_diccionario={
"Nombre":"Ana",
"Ciudad de nacimiento":"Bogotá",
"Empresa":"Amore Group S.A",}

# %%
# Acceder a los elementos del diccionario
print(mi_diccionario["Nombre"])
# Out:
# Ana

# %%
# Modificar un valor en el diccionario
mi_diccionario["Nombre"]="Ana Maria"
print(mi_diccionario)
# Out:
# {'Nombre': 'Ana Maria', 'Ciudad de nacimiento': 'Bogotá', 'Empresa': 'Amore Group S.A'}

# %%
# Añadir un elemento al diccionario
mi_diccionario["Profesión"]="Administradora de empresas"
print(mi_diccionario)
# Out:
# {'Nombre': 'Ana Maria', 'Ciudad de nacimiento': 'Bogotá', 'Empresa': 'Amore Group S.A', 'Profesión': 'Administradora de empresas'}

# %%
# Eliminar un elemento del diccionario
del mi_diccionario["Ciudad de nacimiento"]
print(mi_diccionario)
# Out:
# {'Nombre': 'Ana Maria', 'Empresa': 'Amore Group S.A', 'Profesión': 'Administradora de empresas'}

# %% [markdown]
# # CONDICIONALES

# %%
# Crea un programa que determine si una persona es mayor de edad o menor de edad
print("-------VERIFICACIÓN DE EDAD-----")
edad=int(input("Ingresa tu edad:"))
if edad<18:
  print(f"Eres menor de edad, tienes:{edad}")
else:
  print(f"Eres mayor de edad, tienes:{edad}")
# Out:
# -------VERIFICACIÓN DE EDAD-----
# Ingresa tu edad:30
# Eres mayor de edad, tienes:30

# %%
# Condicionales Múltiples
nota=85
if nota>=80:
  if nota>=90:
    print("Excelente")
  elif nota>=80 and nota<90:
    print("Aceptable")
else:
  print("Insuficiente")
# Out:
# Aceptable
