# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanna112924/ModelosAnaliticosUnicafam202607/blob/main/CLASE_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TALLER ACTUALIZACIÓN DE DATOS

# %%
# DICCIONARIO CON DATOS BASICOS
estudiante={
    "Nombres":"Ana María",
    "Apellidos":"García",
    "Ciudad":"Bogotá",
    "Hijos":"No",
    "Carrera":"Administración de Empresas"}

# %%
# CONSTRUCCIÓN DE MENU DEL USUARIO
print("---- BIENVENIDO A TU PROGRAMA DE ACTUALIZACION DE DATOS----")
print("Para comenzar elige la opción deseada")
print("1.Agregar un dato nuevo")
print("2.Actualizar un dato")
print("3.Eliminar un dato con del")
print("4.Eliminar un dato con pop")
print("5.Consultar un dato")
print("6.Imprimir diccionario completo")
selección=int(input("selecciona la opción deseada:"))
# Out:
# ---- BIENVENIDO A TU PROGRAMA DE ACTUALIZACION DE DATOS----
# Para comenzar elige la opción deseada
# 1.Agregar un dato nuevo
# 2.Actualizar un dato
# 3.Eliminar un dato con del
# 4.Eliminar un dato con pop
# 5.Consultar un dato
# 6.Imprimir diccionario completo
# selecciona la opción deseada:1

# %%
# AGREGAR UN DATO NUEVO
if selección==1:
  clave=input("Ingrese la clave deseada:")
  Valor=input("Ingrese el valor deseado")

  # AGREGAR UN ELEMENTO NUEVO

  estudiante[clave]=Valor
  print("El valor se agrego exitosamente")
  print(estudiante)

  # ACTUALIZAR UN ELEMENTO

elif selección==2:
  clave=input("ingrese la clave a actualizar")
  estudiante[clave]=input("ingrese valor nuevo")
  print("el dato fue actualizado con éxito")
  print(estudiante)

  # ELIMINAR UN ELEMENTO

elif selección==3:
  clave=input("Ingrese la clave a eliminar")
  del estudiante[clave]
  print ("el dato fue eliminado existosamente")
  print(estudiante)

elif selección==4:
  clave=input("Ingrese clave a eliminar")
  estudiante.pop(clave)
  print("El dato fue eliminado exitosamente")
  print(estudiante)

  #CONSULTAR DATO

elif selección==5:
  clave=input("Ingrese clase a consultar")
  valor=estudiante.get(clave,"No disponible")
  print(f"{clave}:{Valor}")

elif selección==6:
  print("perfil completo")
  print(estudiante)


else:
  print("Opcion invalida")
# Out:
# Ingrese la clave deseada:Edad
# Ingrese el valor deseado30
# El valor se agrego exitosamente
# {'Nombres': 'Ana María', 'Apellidos': 'García', 'Ciudad': 'Bogotá', 'Hijos': 'No', 'Carrera': 'Administración de Empresas', 'Edad': '30'}
